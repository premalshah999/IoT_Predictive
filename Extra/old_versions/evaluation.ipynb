# %%
import pandas as pd
from train_models_kfold import prepare_data, get_models_classification, get_models_regression, evaluate_classification, evaluate_regression
df = pd.read_csv('../data/smart_manufacturing_data.csv')
data = prepare_data(df)
# Use only small sample for demonstration
data = data.sample(n=2000, random_state=42)
from sklearn.preprocessing import StandardScaler
X = data.drop(columns=['anomaly_flag','maintenance_required','downtime_risk','predicted_remaining_life','failure_type','machine_id'])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Evaluate one model on anomaly_flag
y = data['anomaly_flag'].values
models = get_models_classification()
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
results = evaluate_classification(X_scaled, y, models)
print(pd.DataFrame(results))
